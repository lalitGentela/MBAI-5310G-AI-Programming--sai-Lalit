# %%
import pandas as pd
from IPython.display import display # used to display tables clearly.

df = pd.read_excel(r"C:\Users\Sai Lalit\Downloads\fitlife_membership_renewal_risk_dataset.xlsx")
print("The Dataset loaded successfully.")

display(df.head())
# Out:
# The Dataset loaded successfully.
# D:\anaconda python\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# D:\anaconda python\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
#   Member_ID  Age             Gender Membership_Type  Monthly_Fee  \
# 0   FS-0001   33               Male        Standard           69
# 1   FS-0002   24             Female        Standard           69
# 2   FS-0003   43             Female           Basic           49
# 3   FS-0004   57  Prefer not to say         Student           35
# 4   FS-0005   35             Female        Standard           54
#
#    Months_As_Member Contract_Type  Avg_Weekly_Visits  Classes_Per_Month  \
# 0                 4       Monthly                2.5                2.0
# ...

# %%
df.shape
# Out:
# (416, 21)

# %%
df.columns
# Out:
# Index(['Member_ID', 'Age', 'Gender', 'Membership_Type', 'Monthly_Fee',
#        'Months_As_Member', 'Contract_Type', 'Avg_Weekly_Visits',
#        'Classes_Per_Month', 'Personal_Training', 'App_Login_Days_Last_30',
#        'Payment_Issues_Last_6_Months', 'Satisfaction_Score',
#        'Complaint_Count_Last_3_Months', 'Distance_From_Studio_km',
#        'Last_Renewal_Discount_Used', 'Renewal_Reminder_Sent', 'Corporate_Plan',
#        'Season', 'Referral_Source', 'At_Risk_Not_Renewing'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Member_ID                      416 non-null    object
#  1   Age                            416 non-null    int64
#  2   Gender                         416 non-null    object
#  3   Membership_Type                416 non-null    object
#  4   Monthly_Fee                    416 non-null    int64
#  5   Months_As_Member               416 non-null    int64
#  6   Contract_Type                  416 non-null    object
#  7   Avg_Weekly_Visits              411 non-null    float64
#  8   Classes_Per_Month              408 non-null    float64
#  9   Personal_Training              416 non-null    object
#  10  App_Login_Days_Last_30         416 non-null    int64
#  11  Payment_Issues_Last_6_Months   416 non-null    int64
# ...

# %%
# Display all column names
print("Dataset columns:")

print(df.columns)
print("\nIn this dataset, we do not have a target variable.")
print("We are not predicting a label such as Yes/No or 0/1.")
print("Instead, we will use customer features to discover hidden customer segments.")
# Out:
# Dataset columns:
# Index(['Member_ID', 'Age', 'Gender', 'Membership_Type', 'Monthly_Fee',
#        'Months_As_Member', 'Contract_Type', 'Avg_Weekly_Visits',
#        'Classes_Per_Month', 'Personal_Training', 'App_Login_Days_Last_30',
#        'Payment_Issues_Last_6_Months', 'Satisfaction_Score',
#        'Complaint_Count_Last_3_Months', 'Distance_From_Studio_km',
#        'Last_Renewal_Discount_Used', 'Renewal_Reminder_Sent', 'Corporate_Plan',
#        'Season', 'Referral_Source', 'At_Risk_Not_Renewing'],
#       dtype='object')
#
# In this dataset, we do not have a target variable.
# We are not predicting a label such as Yes/No or 0/1.
# Instead, we will use customer features to discover hidden customer segments.

# %%
# In supervised learning, we usually define X and y.
# In this unsupervised learning problem, we only define X.

print("Supervised learning: X = features, y = target")
print("Unsupervised learning: X = features only, no y")
# Out:
# Supervised learning: X = features, y = target
# Unsupervised learning: X = features only, no y

# %%
features = [
'Age',
'Gender',
'Membership_Type',
'Monthly_Fee',
'Months_As_Member',
'Contract_Type',
'Avg_Weekly_Visits',
'Classes_Per_Month',
'Personal_Training',
'App_Login_Days_Last_30',
'Payment_Issues_Last_6_Months',
'Satisfaction_Score',
'Complaint_Count_Last_3_Months' ,
'Distance_From_Studio_km',
'Last_Renewal_Discount_Used',
'Renewal_Reminder_Sent',
'Corporate_Plan',
'Season',
'Referral_Source']

x = df[features]

x.head()
# Out:
#    Age             Gender Membership_Type  Monthly_Fee  Months_As_Member  \
# 0   33               Male        Standard           69                 4
# 1   24             Female        Standard           69                 8
# 2   43             Female           Basic           49                25
# 3   57  Prefer not to say         Student           35                27
# 4   35             Female        Standard           54                 1
#
#   Contract_Type  Avg_Weekly_Visits  Classes_Per_Month Personal_Training  \
# 0       Monthly                2.5                2.0                No
# 1       Monthly                4.3                4.0               Yes
# 2       6-Month                1.9                1.0                No
# 3        Annual                2.7                6.0               Yes
# 4       6-Month                3.1                1.0                No
#
#    App_Login_Days_Last_30  Payment_Issues_Last_6_Months  Satisfaction_Score  \
# ...

# %%
# Check the shape of the selected feature dataset

print("Original dataset shape:", df.shape)
print("Selected features shape:", x.shape)
# Out:
# Original dataset shape: (416, 21)
# Selected features shape: (416, 19)

# %%
# Check selected feature names

print("Features selected for clustering:")
print("-" * 50)
for feature in features:
    print("-", feature)
# Out:
# Features selected for clustering:
# --------------------------------------------------
# - Age
# - Gender
# - Membership_Type
# - Monthly_Fee
# - Months_As_Member
# - Contract_Type
# - Avg_Weekly_Visits
# - Classes_Per_Month
# - Personal_Training
# - App_Login_Days_Last_30
# - Payment_Issues_Last_6_Months
# - Satisfaction_Score
# - Complaint_Count_Last_3_Months
# - Distance_From_Studio_km
# - Last_Renewal_Discount_Used
# - Renewal_Reminder_Sent
# - Corporate_Plan
# - Season
# - Referral_Source

# %% [markdown]
# <b> Cleaning the data

# %%
# Clean the Data
# Create a copy of the original dataset

df_clean = df.copy()

# Display original shape
print("Original dataset shape:", df_clean.shape)
# Out:
# Original dataset shape: (416, 21)

# %%
# Clean column names by removing extra spaces

df_clean.columns = df_clean.columns.str.strip()

# Display cleaned column names

df_clean.columns
# Out:
# Index(['Member_ID', 'Age', 'Gender', 'Membership_Type', 'Monthly_Fee',
#        'Months_As_Member', 'Contract_Type', 'Avg_Weekly_Visits',
#        'Classes_Per_Month', 'Personal_Training', 'App_Login_Days_Last_30',
#        'Payment_Issues_Last_6_Months', 'Satisfaction_Score',
#        'Complaint_Count_Last_3_Months', 'Distance_From_Studio_km',
#        'Last_Renewal_Discount_Used', 'Renewal_Reminder_Sent', 'Corporate_Plan',
#        'Season', 'Referral_Source', 'At_Risk_Not_Renewing'],
#       dtype='object')

# %%
# Check duplicate rows

duplicate_count = df_clean.duplicated().sum()
print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 6

# %%
# Remove duplicate rows

df_clean = df_clean.drop_duplicates()
print("Dataset shape after removing duplicates:", df_clean.shape)
# Out:
# Dataset shape after removing duplicates: (410, 21)

# %%
# Check missing values before the next step
df_clean.isnull().sum()
# Out:
# Member_ID                        0
# Age                              0
# Gender                           0
# Membership_Type                  0
# Monthly_Fee                      0
# Months_As_Member                 0
# Contract_Type                    0
# Avg_Weekly_Visits                5
# Classes_Per_Month                8
# Personal_Training                0
# App_Login_Days_Last_30           0
# Payment_Issues_Last_6_Months     0
# Satisfaction_Score               9
# Complaint_Count_Last_3_Months    0
# Distance_From_Studio_km          0
# Last_Renewal_Discount_Used       0
# Renewal_Reminder_Sent            0
# Corporate_Plan                   0
# Season                           0
# Referral_Source                  7
# At_Risk_Not_Renewing             0
# dtype: int64

# %%
# Display the cleaned dataset

df_clean.head()
# Out:
#   Member_ID  Age             Gender Membership_Type  Monthly_Fee  \
# 0   FS-0001   33               Male        Standard           69
# 1   FS-0002   24             Female        Standard           69
# 2   FS-0003   43             Female           Basic           49
# 3   FS-0004   57  Prefer not to say         Student           35
# 4   FS-0005   35             Female        Standard           54
#
#    Months_As_Member Contract_Type  Avg_Weekly_Visits  Classes_Per_Month  \
# 0                 4       Monthly                2.5                2.0
# 1                 8       Monthly                4.3                4.0
# 2                25       6-Month                1.9                1.0
# 3                27        Annual                2.7                6.0
# 4                 1       6-Month                3.1                1.0
#
#   Personal_Training  ...  Payment_Issues_Last_6_Months  Satisfaction_Score  \
# ...

# %%
# handle Missing Values
# Check missing values in the cleaned dataset

df_clean.isnull().sum()
# Out:
# Member_ID                        0
# Age                              0
# Gender                           0
# Membership_Type                  0
# Monthly_Fee                      0
# Months_As_Member                 0
# Contract_Type                    0
# Avg_Weekly_Visits                5
# Classes_Per_Month                8
# Personal_Training                0
# App_Login_Days_Last_30           0
# Payment_Issues_Last_6_Months     0
# Satisfaction_Score               9
# Complaint_Count_Last_3_Months    0
# Distance_From_Studio_km          0
# Last_Renewal_Discount_Used       0
# Renewal_Reminder_Sent            0
# Corporate_Plan                   0
# Season                           0
# Referral_Source                  7
# At_Risk_Not_Renewing             0
# dtype: int64

# %%
# Display the cleaned dataset

df_clean.head()
# Out:
#   Member_ID  Age             Gender Membership_Type  Monthly_Fee  \
# 0   FS-0001   33               Male        Standard           69
# 1   FS-0002   24             Female        Standard           69
# 2   FS-0003   43             Female           Basic           49
# 3   FS-0004   57  Prefer not to say         Student           35
# 4   FS-0005   35             Female        Standard           54
#
#    Months_As_Member Contract_Type  Avg_Weekly_Visits  Classes_Per_Month  \
# 0                 4       Monthly                2.5                2.0
# 1                 8       Monthly                4.3                4.0
# 2                25       6-Month                1.9                1.0
# 3                27        Annual                2.7                6.0
# 4                 1       6-Month                3.1                1.0
#
#   Personal_Training  ...  Payment_Issues_Last_6_Months  Satisfaction_Score  \
# ...

# %%
# Check missing values in the cleaned dataset

df_clean.isnull().sum()
# Out:
# Member_ID                        0
# Age                              0
# Gender                           0
# Membership_Type                  0
# Monthly_Fee                      0
# Months_As_Member                 0
# Contract_Type                    0
# Avg_Weekly_Visits                5
# Classes_Per_Month                8
# Personal_Training                0
# App_Login_Days_Last_30           0
# Payment_Issues_Last_6_Months     0
# Satisfaction_Score               9
# Complaint_Count_Last_3_Months    0
# Distance_From_Studio_km          0
# Last_Renewal_Discount_Used       0
# Renewal_Reminder_Sent            0
# Corporate_Plan                   0
# Season                           0
# Referral_Source                  7
# At_Risk_Not_Renewing             0
# dtype: int64

# %%
# in here the referral source is still showing the value 7. we need to clean this and the some of the numerical columns are showing the same. We need to clean it

numerical_columns = [
'Age',
'Monthly_Fee',
'Months_As_Member',
'Avg_Weekly_Visits',
'Classes_Per_Month',
'App_Login_Days_Last_30',
'Payment_Issues_Last_6_Months',
'Satisfaction_Score',
'Complaint_Count_Last_3_Months',
'Distance_From_Studio_km']

#Catelogical_columns = ['Gender','Membership_Type','Contract_Type','Personal_Training',
                       #'Last_Renewal_Discount_Used','Renewal_Reminder_Sent','Corporate_Plan',
                       #'Season','Referral_Source']

# Fill missing values in numerical columns with the median

for col in numerical_columns:
    df_clean[col] = df_clean[col].fillna(df_clean[col].median())

#for column in Catelogical_columns: 
  #  most_frequent_value = df_clean[column].mode()[0] # Finding the most frequent value in the columns
   # df_clean[column] = df_clean[column].fillna(most_frequent_value) # Filling the frequent values in the columns.     

# Check missing values again
df_clean.isnull().sum()
# Out:
# Member_ID                        0
# Age                              0
# Gender                           0
# Membership_Type                  0
# Monthly_Fee                      0
# Months_As_Member                 0
# Contract_Type                    0
# Avg_Weekly_Visits                0
# Classes_Per_Month                0
# Personal_Training                0
# App_Login_Days_Last_30           0
# Payment_Issues_Last_6_Months     0
# Satisfaction_Score               0
# Complaint_Count_Last_3_Months    0
# Distance_From_Studio_km          0
# Last_Renewal_Discount_Used       0
# Renewal_Reminder_Sent            0
# Corporate_Plan                   0
# Season                           0
# Referral_Source                  0
# At_Risk_Not_Renewing             0
# dtype: int64

# %%
# Recreate X after cleaning and handling missing values

x = df_clean[numerical_columns]

x.head()
# Out:
#    Age  Monthly_Fee  Months_As_Member  Avg_Weekly_Visits  Classes_Per_Month  \
# 0   33           69                 4                2.5                2.0
# 1   24           69                 8                4.3                4.0
# 2   43           49                25                1.9                1.0
# 3   57           35                27                2.7                6.0
# 4   35           54                 1                3.1                1.0
#
#    App_Login_Days_Last_30  Payment_Issues_Last_6_Months  Satisfaction_Score  \
# 0                      19                             0                 6.4
# 1                      30                             1                 6.5
# 2                      11                             2                 9.7
# 3                      16                             0                 7.6
# 4                       7                             2                 7.6
#
# ...

# %%
# Just checking the data set is clear or not

x.isnull().sum()
# Out:
# Age                              0
# Monthly_Fee                      0
# Months_As_Member                 0
# Avg_Weekly_Visits                0
# Classes_Per_Month                0
# App_Login_Days_Last_30           0
# Payment_Issues_Last_6_Months     0
# Satisfaction_Score               0
# Complaint_Count_Last_3_Months    0
# Distance_From_Studio_km          0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# Create the scaler
scaler = StandardScaler()

# Scale the selected features
x_scaled = scaler.fit_transform(x)

# Display the scaled data
x_scaled
# Out:
# array([[-0.24457774,  0.18122184, -0.83943266, ..., -0.7600355 ,
#         -0.50758022,  1.87511756],
#        [-1.08724054,  0.18122184, -0.59039692, ..., -0.69757518,
#         -0.50758022, -0.87827835],
#        [ 0.69171426, -0.64480323,  0.46800497, ...,  1.30115519,
#         -0.50758022,  1.29940751],
#        ...,
#        [-0.43183614, -1.05781577, -0.21684331, ...,  0.92639324,
#          0.66817058,  0.1479874 ],
#        [ 0.31719746, -1.05781577,  0.84155857, ...,  1.05131389,
#         -0.50758022, -0.60293876],
#        [ 0.78534346,  0.80074065,  0.59252283, ..., -0.44773388,
#          3.01967218, -1.00343271]], shape=(410, 10))

# %%
# Convert scaled data back to a DataFrame for better readability

x_scaled_df = pd.DataFrame(x_scaled, columns=numerical_columns)

x_scaled_df.head()
# Out:
#         Age  Monthly_Fee  Months_As_Member  Avg_Weekly_Visits  \
# 0 -0.244578     0.181222         -0.839433          -0.046886
# 1 -1.087241     0.181222         -0.590397           1.464119
# 2  0.691714    -0.644803          0.468005          -0.550555
# 3  2.002523    -1.223021          0.592523           0.121003
# 4 -0.057319    -0.438297         -1.026209           0.456782
#
#    Classes_Per_Month  App_Login_Days_Last_30  Payment_Issues_Last_6_Months  \
# 0          -0.511600                0.388291                     -0.596302
# 1           0.149049                2.283523                      0.747015
# 2          -0.841925               -0.990059                      2.090332
# 3           0.809698               -0.128590                     -0.596302
# 4          -0.841925               -1.679234                      2.090332
#
#    Satisfaction_Score  Complaint_Count_Last_3_Months  Distance_From_Studio_km
# ...

# %%
# Introduction to K-means Clustering

import pandas as pd
kmeans_intro = pd.DataFrame({
            "Concept": [
            "K-means",
            "K",
            "Cluster",
            "Centroid",
            "Business Use"],
    
            "Meaning": [
                "An unsupervised learning algorithm used to group similar data points",
                "The number of clusters selected by the user",
                "A group of similar customers or users",
                "The center point of a cluster",
                "Customer segmentation and pattern discovery"]
})

kmeans_intro
# Out:
#         Concept                                            Meaning
# 0       K-means  An unsupervised learning algorithm used to gro...
# 1             K        The number of clusters selected by the user
# 2       Cluster              A group of similar customers or users
# 3      Centroid                      The center point of a cluster
# 4  Business Use        Customer segmentation and pattern discovery

# %%
# Choosing the number of clusters

import pandas as pd

k_options = pd.DataFrame({
"K Value": [2, 3, 4, 5, 6],
"Meaning": [
"Customers are divided into 2 broad groups",
"Customers are divided into 3 main groups",
"Customers are divided into 4 more detailed groups",
"Customers are divided into 5 smaller groups",
"Customers are divided into 6 very specific groups"]})

k_options
# Out:
#    K Value                                            Meaning
# 0        2          Customers are divided into 2 broad groups
# 1        3           Customers are divided into 3 main groups
# 2        4  Customers are divided into 4 more detailed groups
# 3        5        Customers are divided into 5 smaller groups
# 4        6  Customers are divided into 6 very specific groups

# %%
# Using the elbow method for finding the best K is

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Create an empty list to store inertia values
inertia = []

# Test different values of K
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(x_scaled)
    inertia.append(kmeans.inertia_)
    
# Plot the Elbow Method graph

plt.figure(figsize=(8, 5))
plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Finding the Best K")
plt.show()
# Out:
# D:\anaconda python\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\anaconda python\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\anaconda python\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %% [markdown]
# Analysis of the Elbow Method:-
#
# The Elbow Method graph shows how the inertia value changes when the number of clusters increases.
#
# In the above graph it shows that from K =1 to K = 4 , the inertia decreases sharply. This means that adding more clusters in this
# range improves the grouping of customers significantly.
#
# From K = 4, the curve decreases gradually and smoothly throughout there is no shape. so, K = 4 is where the rate of improvement starts to
# meaningfully slow down.
#
# Therefore, the elbow point appears to be around K = 4.

# %%
# Display inertia values for each K

elbow_results = pd.DataFrame({
        "K": list(K_range),
        "Inertia": inertia})

elbow_results
# Out:
#     K      Inertia
# 0   1  4100.000000
# 1   2  3694.553314
# 2   3  3402.936770
# 3   4  3169.293035
# 4   5  2984.639314
# 5   6  2810.712082
# 6   7  2670.202353
# 7   8  2514.956570
# 8   9  2413.511363
# 9  10  2339.105285

# %%
# Training the K-means model

from sklearn.cluster import KMeans

# Create the K-means model with 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)

# Train the model and assign cluster labels
cluster_labels = kmeans.fit_predict(x_scaled)

# Display the first 10 cluster labels
cluster_labels[:10]
# Out:
# D:\anaconda python\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# array([2, 0, 1, 0, 1, 0, 0, 2, 0, 2], dtype=int32)

# %%
# Check how many customers are in each cluster

import pandas as pd
pd.Series(cluster_labels).value_counts().sort_index()
# Out:
# 0    138
# 1     66
# 2    206
# Name: count, dtype: int64

# %%
# Add Cluster Labels to the Dataset

# Create a copy of the cleaned dataset
df_clustered = df_clean.copy()

# Add cluster labels to the dataset
df_clustered["Cluster"] = cluster_labels

# Display the first five rows
df_clustered.head()
# Out:
#   Member_ID  Age             Gender Membership_Type  Monthly_Fee  \
# 0   FS-0001   33               Male        Standard           69
# 1   FS-0002   24             Female        Standard           69
# 2   FS-0003   43             Female           Basic           49
# 3   FS-0004   57  Prefer not to say         Student           35
# 4   FS-0005   35             Female        Standard           54
#
#    Months_As_Member Contract_Type  Avg_Weekly_Visits  Classes_Per_Month  \
# 0                 4       Monthly                2.5                2.0
# 1                 8       Monthly                4.3                4.0
# 2                25       6-Month                1.9                1.0
# 3                27        Annual                2.7                6.0
# 4                 1       6-Month                3.1                1.0
#
#   Personal_Training  ...  Satisfaction_Score  Complaint_Count_Last_3_Months  \
# ...

# %%
df_clustered[
[
"Member_ID",
"Age",
"Gender",
"Membership_Type",
"Monthly_Fee",
"Months_As_Member",
"Contract_Type",
"Avg_Weekly_Visits",
"Classes_Per_Month",
"Personal_Training",
"App_Login_Days_Last_30",
"Payment_Issues_Last_6_Months",
"Satisfaction_Score",
"Complaint_Count_Last_3_Months", 
"Distance_From_Studio_km",
"Renewal_Reminder_Sent",
"Corporate_Plan",
"Season",
"Referral_Source",
"At_Risk_Not_Renewing",
"Cluster"]].head(10)
# Out:
#   Member_ID  Age             Gender Membership_Type  Monthly_Fee  \
# 0   FS-0001   33               Male        Standard           69
# 1   FS-0002   24             Female        Standard           69
# 2   FS-0003   43             Female           Basic           49
# 3   FS-0004   57  Prefer not to say         Student           35
# 4   FS-0005   35             Female        Standard           54
# 5   FS-0006   28               Male        Standard           64
# 6   FS-0007   26               Male         Premium           84
# 7   FS-0008   28             Female        Standard           59
# 8   FS-0009   35               Male        Standard           59
# 9   FS-0010   34               Male        Standard           54
#
#    Months_As_Member Contract_Type  Avg_Weekly_Visits  Classes_Per_Month  \
# 0                 4       Monthly                2.5                2.0
# 1                 8       Monthly                4.3                4.0
# ...

# %%
# Analyze Cluster Summary

# Calculate the average value of each feature for each cluster
cluster_summary = df_clustered.groupby("Cluster")[numerical_columns].mean()

# Display the cluster summary
cluster_summary
# Out:
#                Age  Monthly_Fee  Months_As_Member  Avg_Weekly_Visits  \
# Cluster
# 0        39.572464    70.014493         18.528986           3.493478
# 1        32.575758    74.939394         16.287879           2.180303
# 2        33.932039    57.684466         17.165049           2.048058
#
#          Classes_Per_Month  App_Login_Days_Last_30  \
# Cluster
# 0                 5.594203               20.471014
# 1                 3.696970               15.803030
# 2                 2.131068               14.553398
#
#          Payment_Issues_Last_6_Months  Satisfaction_Score  \
# Cluster
# 0                            0.231884            7.989855
# 1                            1.772727            6.318182
# 2                            0.160194            7.783010
#
#          Complaint_Count_Last_3_Months  Distance_From_Studio_km
# Cluster
# 0                             0.413043                 6.159420
# 1                             0.469697                 5.996970
# ...

# %%
# Round the values for easier interpretation

cluster_summary_rounded = cluster_summary.round(2)
cluster_summary_rounded
# Out:
#            Age  Monthly_Fee  Months_As_Member  Avg_Weekly_Visits  \
# Cluster
# 0        39.57        70.01             18.53               3.49
# 1        32.58        74.94             16.29               2.18
# 2        33.93        57.68             17.17               2.05
#
#          Classes_Per_Month  App_Login_Days_Last_30  \
# Cluster
# 0                     5.59                   20.47
# 1                     3.70                   15.80
# 2                     2.13                   14.55
#
#          Payment_Issues_Last_6_Months  Satisfaction_Score  \
# Cluster
# 0                                0.23                7.99
# 1                                1.77                6.32
# 2                                0.16                7.78
#
#          Complaint_Count_Last_3_Months  Distance_From_Studio_km
# Cluster
# 0                                 0.41                     6.16
# 1                                 0.47                     6.00
# ...

# %%
# Count the number of customers in each cluster

cluster_counts = df_clustered["Cluster"].value_counts().sort_index()
cluster_counts
# Out:
# Cluster
# 0    138
# 1     66
# 2    206
# Name: count, dtype: int64

# %%
# Create a summary table with customer counts and average feature values

cluster_summary_final = cluster_summary_rounded.copy()
cluster_summary_final["Number_of_Customers"] = cluster_counts
cluster_summary_final
# Out:
#            Age  Monthly_Fee  Months_As_Member  Avg_Weekly_Visits  \
# Cluster
# 0        39.57        70.01             18.53               3.49
# 1        32.58        74.94             16.29               2.18
# 2        33.93        57.68             17.17               2.05
#
#          Classes_Per_Month  App_Login_Days_Last_30  \
# Cluster
# 0                     5.59                   20.47
# 1                     3.70                   15.80
# 2                     2.13                   14.55
#
#          Payment_Issues_Last_6_Months  Satisfaction_Score  \
# Cluster
# 0                                0.23                7.99
# 1                                1.77                6.32
# 2                                0.16                7.78
#
#          Complaint_Count_Last_3_Months  Distance_From_Studio_km  \
# Cluster
# 0                                 0.41                     6.16
# 1                                 0.47                     6.00
# ...

# %%
# Identify clusters based on customer behavior
summary = cluster_summary_final.copy()

# Cluster with the highest spending score
high_spender_cluster = summary["Months_As_Member"].idxmax()

# Cluster with the highest income among the remaining clusters
remaining_clusters = summary.drop(index=high_spender_cluster)
premium_cluster = remaining_clusters["Monthly_Fee"].idxmax()

# The remaining cluster is considered low engagement / low spending
low_engagement_cluster = summary.drop(index=[high_spender_cluster,premium_cluster]).index[0]
# Create business names for clusters
segment_names = {
        high_spender_cluster: "Active High Spenders",
        premium_cluster: "High-Income Premium Buyers",
        low_engagement_cluster: "Low-Engagement Customers"
}

# Add segment names to the dataset
df_clustered["Segment_Name"] = df_clustered["Cluster"].map(segment_names)

# Display the first rows
df_clustered.head()
# Out:
#   Member_ID  Age             Gender Membership_Type  Monthly_Fee  \
# 0   FS-0001   33               Male        Standard           69
# 1   FS-0002   24             Female        Standard           69
# 2   FS-0003   43             Female           Basic           49
# 3   FS-0004   57  Prefer not to say         Student           35
# 4   FS-0005   35             Female        Standard           54
#
#    Months_As_Member Contract_Type  Avg_Weekly_Visits  Classes_Per_Month  \
# 0                 4       Monthly                2.5                2.0
# 1                 8       Monthly                4.3                4.0
# 2                25       6-Month                1.9                1.0
# 3                27        Annual                2.7                6.0
# 4                 1       6-Month                3.1                1.0
#
#   Personal_Training  ...  Complaint_Count_Last_3_Months  \
# 0                No  ...                              0
# ...

# %%
segment_interpretation = pd.DataFrame({
    "Cluster": [0, 1, 2, 3],
    "Segment Name": [
        "Loyal Engaged Members",
        "Premium Dissatisfied Members",
        "Budget Low-Activity Members",
        "At-Risk Complaint-Prone Members"
    ],
    "Business Interpretation": [
        "High visits, high app use, high satisfaction, long tenure.",
        "Pay the highest fees but visit least and are least satisfied.",
        "Largest group, low engagement, moderate satisfaction, lowest fees.",
        "Newest members, dramatically higher complaint count than all other groups."
    ],
    "Possible Business Strategy": [
        "Loyalty rewards, early renewal incentives, referral bonuses, exclusive member events.",
        "Proactive outreach, service quality review, personalised check-ins, fee-value alignment.",
        "Class variety promotions, gamified attendance challenges, upgrade incentives.",
        "Immediate complaint resolution pipeline, personal trainer introductions, satisfaction follow-ups."
    ]
})

segment_interpretation
# Out:
#    Cluster                     Segment Name  \
# 0        0            Loyal Engaged Members
# 1        1     Premium Dissatisfied Members
# 2        2      Budget Low-Activity Members
# 3        3  At-Risk Complaint-Prone Members
#
#                              Business Interpretation  \
# 0  High visits, high app use, high satisfaction, ...
# 1  Pay the highest fees but visit least and are l...
# 2  Largest group, low engagement, moderate satisf...
# 3  Newest members, dramatically higher complaint ...
#
#                           Possible Business Strategy
# 0  Loyalty rewards, early renewal incentives, ref...
# 1  Proactive outreach, service quality review, pe...
# 2  Class variety promotions, gamified attendance ...
# 3  Immediate complaint resolution pipeline, perso...

# %%
# Check how many customers are in each named segment

df_clustered["Segment_Name"].value_counts()
# Out:
# Segment_Name
# Low-Engagement Customers      206
# Active High Spenders          138
# High-Income Premium Buyers     66
# Name: count, dtype: int64

# %%
# Visualize Clusters Using Two Features

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(
df_clustered["Monthly_Fee"],
df_clustered["Months_As_Member"],
c=df_clustered["Cluster"],
alpha=0.7
)
plt.xlabel("Monthly Fee")
plt.ylabel("Months As Member")
plt.title("Customer Clusters Using Monthly Fee and Months As Member")
plt.colorbar(label="Cluster")
plt.show()

# %%
# Visualize clusters using segment names

plt.figure(figsize=(8, 6))
for segment in df_clustered["Segment_Name"].unique():
    segment_data = df_clustered[df_clustered["Segment_Name"] == segment]
    plt.scatter(
    segment_data["Monthly_Fee"],
    segment_data["Months_As_Member"],
    label=segment,
    alpha=0.7
)
plt.xlabel("Monthly Fee")
plt.ylabel("Months As Member")
plt.title("Customer Segments Using Monthly Fee and Months As Member")
plt.legend()
plt.show()
